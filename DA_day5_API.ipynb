# %%
import requests

# %%
page=requests.get('https://randomfox.ca/floof')

# %%
print(page.status_code)
# Out:
# 200

# %%
print(page.text)
# Out:
# {"image":"https:\/\/randomfox.ca\/images\/121.jpg","link":"https:\/\/randomfox.ca\/?i=121"}

# %%
print(page.json())
# Out:
# {'image': 'https://randomfox.ca/images/121.jpg', 'link': 'https://randomfox.ca/?i=121'}

# %%
from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json

url = 'https://sandbox-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
parameters = {
  'start':'1',
  'limit':'5000',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': 'a9ec5509-1517-48db-8ef2-4502bef8e185',
}

session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
  print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)
# Out:
# {'status': {'timestamp': '2024-02-16T10:42:25.729Z', 'error_code': 0, 'error_message': None, 'elapsed': 1, 'credit_count': 1, 'notice': None}, 'data': [{'id': 8788, 'name': 'j0edmts9nv9', 'symbol': 'a7amblx5iga', 'slug': 'flrnh810fr', 'cmc_rank': 5351, 'num_market_pairs': 5223, 'circulating_supply': 6427, 'total_supply': 5084, 'max_supply': 9363, 'infinite_supply': None, 'last_updated': '2024-02-16T10:42:25.728Z', 'date_added': '2024-02-16T10:42:25.728Z', 'tags': ['szrp19jezjs', '39u1onvm2tg', 'qjwor9hvi1a', 'umfgcal8ud', 'y3q1ilgmoz', 'pcu21h3r2i', 'djd30tzd4h', 'bcnbmw1wmmo', 'ogj882vnj7s', 'rq40t8vkvyc'], 'platform': None, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'quote': {'USD': {'price': 0.20258573959692439, 'volume_24h': 1222, 'volume_change_24h': 0.9925453451243735, 'percent_change_1h': 0.9583237264412416, 'percent_change_24h': 0.32937113897498205, 'percent_change_7d': 0.042162975206333275, 'market_cap': 0.18013649458561254, 'market_cap_dominance': 3088, 'fully_diluted_market_cap': 0.07902234287918652, 'last_updated': '2024-02-16T10:42:25.728Z'}}}, {'id': 7790, 'name': 'xv8i0mxul1q', 'symbol': 'l2j3oxnnh7', 'slug': 'x6tv0u4sv2c', 'cmc_rank': 31, 'num_market_pairs': 5893, 'circulating_supply': 9109, 'total_supply': 3137, 'max_supply': 1997, 'infinite_supply': None, 'last_updated': '2024-02-16T10:42:25.728Z', 'date_added': '2024-02-16T10:42:25.728Z', 'tags': ['scr879vd4z', 'i1mthfnm8ml', '45modu2sj8t', 'snbwsjunzes', 'ubcq2afio5g', 'gx418gfgmlt', 'bnvdc357uoa', 'plysl4u5gb', 'xw2btj4h9l', '60ae1gyjm2x'], 'platform': None, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'quote': {'USD': {'price': 0.8340607947833492, 'volume_24h': 2574, 'volume_change_24h': 0.5394388579152538, 'percent_change_1h': 0.229332082571428, 'percent_change_24h': 0.63444603363767, 'percent_change_7d': 0.7821779627739938, 'market_cap': 0.35052063498792996, 'market_cap_dominance': 621, 'fully_diluted_market_cap': 0.6421790058904517, 'last_updated': '2024-02-16T10:42:25.728Z'}}}, {'id': 2982, 'name': '3lbxigtkcjl', 'symbol': '7kh0r84xq5x', 'slug': 'cfn5mg6geg', 'cmc_rank': 6991, 'num_market_pairs': 8407, 'circulating_supply': 3084, 'total_supply': 6902, 'max_supply': 160, 'infinite_supply': None, 'last_updated': '2024-02-16T10:42:25.728Z', 'date_added': '2024-02-16T10:42:25.728Z', 'tags': ['87ttxks6jy5', '1ehkud981iu', 'v79pp9exe5', '7rthlhz3rot', 'qko728p208h', '25qnjeqvmcd', 'wmil3fma7sd', 'cf97ikdwq2v', 'hc4a91h30kw', 'wrnuaxm8jni'], 'platform': None, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'quote': {'USD': {'price': 0.22200914220722923, 'volume_24h': 516, 'volume_change_24h': 0.7880679351975877, 'percent_change_1h': 0.3445819154057903, 'percent_change_24h': 0.778047721204066, 'percent_change_7d': 0.28369758637665754, 'market_cap': 0.8761908336310287, 'market_cap_dominance': 6332, 'fully_diluted_market_cap': 0.1496843565354098, 'last_updated': '2024-02-16T10:42:25.728Z'}}}, {'id': 2289, 'name': 'd3zxntr6ao6', 'symbol': 'foujgluuo6', 'slug': 'e3weohfu1zf', 'cmc_rank': 69, 'num_market_pairs': 1852, 'circulating_supply': 1229, 'total_supply': 3463, 'max_supply': 84, 'infinite_supply': None, 'last_updated': '2024-02-16T10:42:25.728Z', 'date_added': '2024-02-16T10:42:25.728Z', 'tags': ['dmj1grh4cl5', '7kmodn4f6yy', 'huq6q6citrt', 'ddcgev56vyn', 'c09ec7q9gb5', '00iryxu6sxll5', 'iyergot33mj', 'f99b90fru9', 'n3gt1fy1fip', 'q5rbvvh3ozj'], 'platform': None, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'quote': {'USD': {'price': 0.4052976937870889, 'volume_24h': 4071, 'volume_change_24h': 0.7421739930529376, 'percent_change_1h': 0.9651416702530362, 'percent_change_24h': 0.5719133431636567, 'percent_change_7d': 0.33126273086053737, 'market_cap': 0.47193249988363495, 'market_cap_dominance': 7611, 'fully_diluted_market_cap': 0.1034213561859767, 'last_updated': '2024-02-16T10:42:25.728Z'}}}, {'id': 2737, 'name': 'z76yy98ro1o', 'symbol': ...

# %%
type(data)
# Out:
# dict

# %%
import pandas as pd
norm=pd.json_normalize(data['data'])

# %%
norm
# Out:
#      id         name       symbol         slug  cmc_rank  num_market_pairs  \
# 0  8788  j0edmts9nv9  a7amblx5iga   flrnh810fr      5351              5223
# 1  7790  xv8i0mxul1q   l2j3oxnnh7  x6tv0u4sv2c        31              5893
# 2  2982  3lbxigtkcjl  7kh0r84xq5x   cfn5mg6geg      6991              8407
# 3  2289  d3zxntr6ao6   foujgluuo6  e3weohfu1zf        69              1852
# 4  2737  z76yy98ro1o  8lj7jzhdrjx  pzzxoaizekq      2180               137
# 5  5042  a7f48sbtntd  jpwdqg7isfb   xj1rt7rxbz      9827              2061
# 6  5692   wf0yqqcqla  f8yt280zx5n  tawbg0fpllp      3927              7875
# 7  2025  1poru15x9h7   wto0ue82qa  qbg6zkjg5un      6850              9300
# 8  8070  7cbtiskys8x   oz0qkz0o1x   sv5ymur34m      5392              6395
# 9  6895  ddagj9fpz8i  7nb777nk2q3  x4usj6f7apm      6872              5753
#
#    circulating_supply  total_supply  max_supply infinite_supply  ...  \
# 0                6427          5084        9363            None  ...
# 1                9109          3137        1997            None  ...
# 2                3084          6902         160            None  ...
# 3                1229          3463          84            None  ...
# 4                8223          9795        3243            None  ...
# 5                3680          3504        1074            None  ...
# 6                2190          1993        2926            None  ...
# 7                8485          9313        2887            None  ...
# 8                3212          9720        9056            None  ...
# 9                4047          2264        3133            None  ...
#
#   quote.USD.price quote.USD.volume_24h quote.USD.volume_change_24h  \
# 0        0.202586                 1222                    0.992545
# 1        0.834061                 2574                    0.539439
# 2        0.222009                  516                    0.788068
# 3        0.405298                 4071                    0.742174
# 4        0.105371                 3407                    0.557377
# 5        0.036959                 6668                    0.638696
# 6        0.938879                 1418                    0.366380
# 7        0.690774                 1584                    0.937198
# 8        0.733325                 4279                    0.122262
# 9        0.925509                 1224                    0.238768
#
#   quote.USD.percent_change_1h quote.USD.percent_change_24h  \
# 0                    0.958324                     0.329371
# 1                    0.229332                     0.634446
# 2                    0.344582                     0.778048
# 3                    0.965142                     0.571913
# 4                    0.869838                     0.645002
# 5                    0.380855                     0.679297
# 6                    0.721449                     0.679367
# 7                    0.550623                     0.082361
# 8                    0.182875                     0.308957
# 9                    0.773558                     0.047236
#
#   quote.USD.percent_change_7d  quote.USD.market_cap  \
# 0                    0.042163              0.180136
# 1                    0.782178              0.350521
# 2                    0.283698              0.876191
# 3                    0.331263              0.471932
# 4                    0.994301              0.197286
# 5                    0.220309              0.101665
# 6                    0.271700              0.952230
# 7                    0.308588              0.292041
# 8                    0.902881              0.926077
# 9                    0.995473              0.086338
#
#    quote.USD.market_cap_dominance  quote.USD.fully_diluted_market_cap  \
# 0                            3088                            0.079022
# 1                             621                            0.642179
# 2                            6332                            0.149684
# 3                            7611                            0.103421
# 4                            4320                            0.566564
# 5                            9653                            0.354299
# 6                            4099                            0.077345
# 7                            2578                            0.421245
# 8                            2386                            0.940555
# 9                            7234                            0.506589
#
#      quote.USD.last_updated
# 0  2024-02-16T10:42:25.728Z
# 1  2024-02-16T10:42:25.728Z
# 2  2024-02-16T10:42:25.728Z
# 3  2024-02-16T10:42:25.728Z
# 4  2024-02-16T10:42:25.728Z
# 5  2024-02-16T10:42:25.728Z
# 6  2024-02-16T10:42:25.728Z
# 7  2024-02-16T10:42:25.728Z
# 8  2024-02-16T10:42:25.728Z
# 9  2024-02-16T10:42:25.728Z
#
# [10 rows x 26 columns]
